# %% [markdown]
# Retos de Hacker Rank  - Python

# %%
import math
import os
import random
import re
import sys

# %% [markdown]
# Reto # 3 - Arithmetic Operators
#
# Task
# Read two integers from STDIN and print three lines where:
#
# The first line contains the sum of the two numbers.
# The second line contains the difference of the two numbers (first - second).
# The third line contains the product of the two numbers.
# Input Format
#
# The first line contains the first integer, . The second line contains the second integer, .
#
# Constraints
#
#
#
# Output Format
#
# Print the three lines as explained above.

# %%
# Reto #3 Python Arithmetic Operators


vble_error="Error - No se encuentra en el rango permitido"

n1 = int(input())
n2 = int(input())

if (n1>1) & (n2>1) & (n1 <= 10000000) & (n2 <= 10000000):
    print(n1 + n2)
else:
    print(vble_error)

# %% [markdown]
# Reto 4 - Python division
# Task
# Read two integers and print two lines. The first line should contain integer division,  // . The second line should contain float division,  / .
#
# You don't need to perform any rounding or formatting operations.
#
# Input Format
#
# The first line contains the first integer, . The second line contains the second integer, .
#
# Output Format
#
# Print the two lines as described above.

# %%
# Reto #4 Python: Division


vble_error="Error - División por cero"

n1 = float(input())
n2 = float(input())

if (n1 != 0) :
    print(int(n1 / n2))
    print(float(n1 / n2))
else:
    print(vble_error)
# Out:
# 4
# 3
# 1
# 1.3333333333333333
